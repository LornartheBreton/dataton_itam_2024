# %%
import osmium
import csv

# %%
import osmium
import shapely.wkb as wkblib
from shapely.geometry import shape

class PharmacyHandler(osmium.SimpleHandler):
    def __init__(self):
        super(PharmacyHandler, self).__init__()
        self.pharmacies = []
        self.wkbfab = osmium.geom.WKBFactory()

    def node(self, n):
        if self.is_pharmacy(n.tags):
            pharmacy_data = self.extract_pharmacy_data(n)
            self.pharmacies.append(pharmacy_data)

    def way(self, w):
        if self.is_pharmacy(w.tags):
            centroid = self.calculate_centroid(w)
            pharmacy_data = self.extract_pharmacy_data(w, centroid)
            self.pharmacies.append(pharmacy_data)

    def relation(self, r):
        if self.is_pharmacy(r.tags):
            centroid = self.calculate_centroid(r)
            pharmacy_data = self.extract_pharmacy_data(r, centroid)
            self.pharmacies.append(pharmacy_data)

    def is_pharmacy(self, tags):
        # List of known pharmacy chain names
        pharmacy_chains = [
            'Farmacias Similares',
            'Farmacias Guadalajara',
            'Farmacias del Ahorro',
            'Farmacias Benavides',
            'Farmacia San Pablo',
            # Add more chains as needed
        ]

        if ('amenity' in tags and tags['amenity'] == 'pharmacy') or \
           ('shop' in tags and tags['shop'] == 'chemist') or \
           ('healthcare' in tags and tags['healthcare'] == 'pharmacy') or \
           ('dispensing' in tags and tags['dispensing'] == 'yes'):
            return True

        # Check if 'farmacia' or 'pharmacy' is in the name
        if 'name' in tags:
            name_lower = tags['name'].lower()
            if 'farmacia' in name_lower or 'pharmacy' in name_lower:
                return True
            # Check if the name matches a known pharmacy chain
            for chain in pharmacy_chains:
                if chain.lower() in name_lower:
                    return True
        return False

    def calculate_centroid(self, element):
        try:
            if isinstance(element, osmium.osm.Way):
                if element.is_closed():
                    wkb = self.wkbfab.create_polygon(element)
                else:
                    wkb = self.wkbfab.create_linestring(element)
            elif isinstance(element, osmium.osm.Relation):
                wkb = self.wkbfab.create_multipolygon(element)
            else:
                return (None, None)

            geom = wkblib.loads(wkb, hex=True)
            centroid = geom.centroid
            return (centroid.y, centroid.x)
        except Exception as e:
            print(f"Error calculating centroid for element {element.id}: {e}")
            return (None, None)

    def extract_pharmacy_data(self, element, centroid=None):
        tags = dict(element.tags)
        pharmacy_data = {
            'id': element.id,
            'type': element.__class__.__name__.lower(),  # 'node', 'way', or 'relation'
            'latitude': centroid[0] if centroid else getattr(element.location, 'lat', None),
            'longitude': centroid[1] if centroid else getattr(element.location, 'lon', None),
            'name': tags.get('name'),
            'street': tags.get('addr:street'),
            'housenumber': tags.get('addr:housenumber'),
            'city': tags.get('addr:city'),
            'postcode': tags.get('addr:postcode'),
            'state': tags.get('addr:state'),
            'country': tags.get('addr:country'),
            'phone': tags.get('phone') or tags.get('contact:phone'),
            'email': tags.get('email') or tags.get('contact:email'),
            'website': tags.get('website') or tags.get('contact:website'),
            'opening_hours': tags.get('opening_hours'),
            'operator': tags.get('operator'),
            'brand': tags.get('brand'),
            'brand_wikidata': tags.get('brand:wikidata'),
 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1172850368: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1175118412: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1175169557: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1175169558: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1175169560: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1175209528: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1176041377: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1177907036: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1180698817: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1180708003: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1180730400: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1180750930: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1181783768: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1181977379: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1181977381: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1181977384: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1186139087: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1189226512: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1189780033: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1189960982: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1191883817: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1191901975: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1191901976: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1192524161: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1192782877: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1192782885: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1192800097: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1193873567: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1194908620: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1194908621: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1196094862: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1196906196: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1198202785: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1198221141: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1201199289: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1211972288: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1212887756: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1213693005: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1217141438: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1217897894: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1219437952: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1223649250: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1228085541: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1228369753: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1228880358: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1228889638: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1230249634: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1232245927: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1232291499: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1232539893: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1235110928: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1239205674: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1241567340: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1242017461: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1249426542: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1249430402: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1254665201: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1254676518: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1258112556: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1263654779: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1264577612: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1264693528: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1265002050: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1265002065: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1265067131: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1270174070: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1272611007: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1272615685: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1272985476: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1273394478: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1275409943: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1275581541: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1275581542: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1278077059: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1278455681: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1280371314: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1280371315: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1283714484: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1286131909: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1286131918: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1286131920: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1286135902: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1290380614: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1291195562: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1291208474: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1291868667: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1301756747: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1304063460: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1304063467: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1304156614: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1304542628: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1304721992: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1304722000: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1306712092: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1308317737: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1311341497: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1313349925: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1314731303: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1314731345: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1314731545: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 1315457059: 'osmium.geom.WKBFactory' object has no attribute 'create_polygon'
# Error calculating centroid for element 13640524: Unable to cast Python instance of type <class 'osmium.osm._osm.COSMRelation'> to C++ type '?' (#define PYBIND11_DETAILED_ERROR_MESSAGES or compile in debug mode for details)
# Error calculating centroid for element 13976796: Unable to cast Python instance of type <class 'osmium.osm._osm.COSMRelation'> to C++ type '?' (#define PYBIND11_DETAILED_ERROR_MESSAGES or compile in debug mode for details)
# Error calculating centroid for element 16147160: Unable to cast Python instance of type <class 'osmium.osm._osm.COSMRelation'> to C++ type '?' (#define PYBIND11_DETAILED_ERROR_MESSAGES or compile in debug mode for details)

# %%
pharmacies = handler.pharmacies

# Optional: Save to a CSV file
fieldnames = [
    'id', 'type', 'latitude', 'longitude', 'name', 'street', 'housenumber', 'city', 'postcode',
    'state', 'country', 'phone', 'email', 'website', 'opening_hours', 'operator', 'brand',
    'brand_wikidata', 'brand_wikipedia', 'wheelchair', 'drive_through', 'dispensing',
    'osm_version', 'timestamp', 'changeset', 'user', 'uid'
]

with open('pharmacies_mexico.csv', 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    for pharmacy in pharmacies:
        writer.writerow(pharmacy)

print(f"Extracted {len(pharmacies)} pharmacies.")
# Out:
# Extracted 5939 pharmacies.

# %%
len(pharmacies)
# Out:
# 5523

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('pharmacies_mexico.csv')

# %%
df.head()
# Out:
#           id  type   latitude   longitude                  name street  \
# 0  280308494  node  20.604881 -105.233711  Farmacia Guadalajara    NaN
# 1  293542771  node  25.667318 -100.312021             Benavides    NaN
# 2  309251520  node  16.730159  -92.640593  Farmacias del Ahorro    NaN
# 3  332364266  node  19.344371  -99.188942  Farmacias del Ahorro    NaN
# 4  337877608  node  17.640843 -101.555545           Farmapronto    NaN
#
#   housenumber city  postcode state  ... brand_wikidata brand_wikipedia  \
# 0         NaN  NaN       NaN   NaN  ...       Q5435609             NaN
# 1         NaN  NaN       NaN   NaN  ...       Q5435613             NaN
# 2         NaN  NaN       NaN   NaN  ...      Q62086647             NaN
# 3         NaN  NaN       NaN   NaN  ...      Q62086647             NaN
# 4         NaN  NaN       NaN   NaN  ...            NaN             NaN
#
#   wheelchair drive_through dispensing osm_version                  timestamp  \
# 0        NaN           NaN        NaN           6  2024-05-17T15:40:48+00:00
# 1        NaN           NaN        NaN           8  2023-03-30T07:16:48+00:00
# 2        NaN           NaN        NaN           3  2022-05-20T21:41:56+00:00
# 3        NaN           NaN        NaN           3  2022-07-12T01:18:14+00:00
# 4        NaN           NaN        yes           2  2013-01-07T03:37:46+00:00
#
#   changeset user uid
# 0         0  NaN   0
# 1         0  NaN   0
# 2         0  NaN   0
# 3         0  NaN   0
# 4         0  NaN   0
#
# [5 rows x 27 columns]

# %%
df.columns
# Out:
# Index(['id', 'type', 'latitude', 'longitude', 'name', 'street', 'housenumber',
#        'city', 'postcode', 'state', 'country', 'phone', 'email', 'website',
#        'opening_hours', 'operator', 'brand', 'brand_wikidata',
#        'brand_wikipedia', 'wheelchair', 'drive_through', 'dispensing',
#        'osm_version', 'timestamp', 'changeset', 'user', 'uid'],
#       dtype='object')

# %%
df['brand']
# Out:
# 0       Farmacia Guadalajara
# 1                  Benavides
# 2       Farmacias del Ahorro
# 3       Farmacias del Ahorro
# 4                        NaN
#                 ...
# 5518    Farmacia Guadalajara
# 5519    Farmacia Guadalajara
# 5520               Benavides
# 5521                     NaN
# 5522    Farmacia Guadalajara
# Name: brand, Length: 5523, dtype: object

# %%
df['brand'].value_counts()
# Out:
# brand
# Farmacia Guadalajara        626
# Farmacias Similares         523
# Farmacias del Ahorro        429
# Benavides                   233
# Farmacia Benavides           43
# Farmacias Yza                34
# Farmatodo                    28
# Farmacia Similares           24
# Farmacias Unión              12
# Farmacias del Dr. Simi       10
# Farmahorro                    2
# Farmacias YZA                 1
# Farmacias Ahumada             1
# Farmacia GI                   1
# Benu                          1
# Farmacias Especializadas      1
# Farmacia San Pablo            1
# Name: count, dtype: int64

# %%
df['name'].value_counts().head(30)
# Out:
# name
# Farmacia Guadalajara        754
# Farmacias Similares         633
# Farmacias del Ahorro        519
# Benavides                   263
# Farmacias Guadalajara        78
# Farmacia Similares           65
# Farmacia Benavides           63
# Farmacias Yza                52
# Similares                    39
# Farmacia San Pablo           33
# Farmacia del Ahorro          32
# Guadalajara                  31
# Farmatodo                    30
# Farmacias Benavides          27
# Farmapronto                  26
# Farmacia                     25
# San Pablo                    22
# Farmacias Especializadas     20
# Farmacias GI                 16
# Farmacias YZA                15
# Farmacia Yza                 13
# Farmacias Unión              13
# Farmacia GI                  12
# Farmacias Sufacen            11
# Farmacia Roma                11
# Del Ahorro                   10
# Farmacon                     10
# Farmacias similares          10
# Yza                          10
# Farmacias del Dr. Simi       10
# Name: count, dtype: int64
