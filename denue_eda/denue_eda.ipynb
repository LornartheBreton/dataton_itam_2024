# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('farmacias.csv')
# Out:
# /tmp/ipykernel_1211/290964931.py:1: DtypeWarning: Columns (35) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('farmacias.csv')

# %%
df
# Out:
#         id                          clee  \
# 0    23279  01001433110000172000000000U8
# 1  8217258  01001464111004021000000000U3
# 2    35681  01001464113000381000000000U1
# 3  6943828  01001464111003431000000000U5
# 4  7162977  01001464111003271000000000U5
#
#                                            nom_estab  \
# 0  ABASTECEDORA MEDICA HOSPITALARIA DE AGUASCALIE...
# 1                               BIOFARMACIA FAMILIAR
# 2                       BOTICA OMEOPATICA HAHANEMANN
# 3                                  CLUB DE NUTRICION
# 4                       CLUB DE NUTRICION HERBA LIFE
#
#                                           raz_social  codigo_act  \
# 0  ABASTECEDORA MEDICA HOSPITALARIA DE AGUASCALIE...      464111
# 1                                                NaN      464111
# 2                                                NaN      464111
# 3                                                NaN      464111
# ...
